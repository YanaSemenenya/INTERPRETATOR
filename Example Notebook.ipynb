# %%
import yanapy

# %%
from yanapy.interpretators.baseinterpretator import BaseInterpretator

# %%
import yanapy.interpretators as inter

# %%
inter.baseinterpretator.BaseInterpretator
# Out:
# yanapy.interpretators.baseinterpretator.BaseInterpretator
